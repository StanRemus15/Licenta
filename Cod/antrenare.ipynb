# %%
import os

from sklearn.metrics import confusion_matrix, classification_report

os.environ['TF_ENABLE_ONEDNN_OPTS']= '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import keras as kr
from keras.callbacks import EarlyStopping

from sklearn.utils.class_weight import compute_class_weight

# %%
set_date_antrenare = kr.utils.image_dataset_from_directory(
    'D:/Licenta/DataSetOrganized/data/train',
    labels="inferred",
    label_mode="int",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(256, 256),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False,
    pad_to_aspect_ratio=False,
    data_format=None,
    format="tf",
    verbose=True,
)

set_date_validare = kr.utils.image_dataset_from_directory(
    'D:/Licenta/DataSetOrganized/data/validation',
    labels="inferred",
    label_mode="int",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(256, 256),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False,
    pad_to_aspect_ratio=False,
    data_format=None,
    format="tf",
    verbose=True,
)

set_date_testare = kr.utils.image_dataset_from_directory(
    'D:/Licenta/DataSetOrganized/data/test',
    labels="inferred",
    label_mode="int",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(256, 256),
    shuffle=False,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False,
    pad_to_aspect_ratio=False,
    data_format=None,
    format="tf",
    verbose=True,
)
# Out:
# Found 3000 files belonging to 5 classes.
# Found 600 files belonging to 5 classes.
# Found 400 files belonging to 5 classes.

# %%
model_data_augumentation = kr.Sequential([kr.layers.RandomFlip("horizontal_and_vertical"),kr.layers.RandomBrightness(0.1),kr.layers.RandomContrast(0.1)],name="augumentare_date")

# %%
def squeeze_excite_block(tensor,ratio=8):
    filters = tensor.shape[-1]
    s_e_b = kr.layers.GlobalAvgPool2D()(tensor)
    s_e_b = kr.layers.Dense(filters // ratio,activation = 'relu' , kernel_initializer='he_normal')(s_e_b)
    s_e_b = kr.layers.Dense(filters,activation='sigmoid')(s_e_b)
    s_e_b = kr.layers.Reshape((1,1,filters))(s_e_b)
    return kr.layers.Multiply()([tensor,s_e_b])

# %%
inputs = kr.layers.Input(shape=(256,256,3))


x = model_data_augumentation(inputs)
x =  kr.layers.Rescaling(1./255)(x)

x = kr.layers.Conv2D(64,3,padding ='same',kernel_initializer='he_normal')(x)
x = kr.layers.BatchNormalization()(x)
x = kr.layers.Activation('relu')(x)
x = squeeze_excite_block(x)
x = kr.layers.MaxPooling2D(2,2)(x)

x = kr.layers.Conv2D(128,3,padding ='same',kernel_initializer='he_normal')(x)
x = kr.layers.BatchNormalization()(x)
x = kr.layers.Activation('relu')(x)
x = squeeze_excite_block(x)
x = kr.layers.MaxPooling2D(2,2)(x)


x = kr.layers.Conv2D(256,3,padding ='same',kernel_initializer='he_normal')(x)
x = kr.layers.BatchNormalization()(x)
x = kr.layers.Activation('relu')(x)
x = squeeze_excite_block(x)
x = kr.layers.MaxPooling2D(2,2)(x)


x = kr.layers.GlobalAveragePooling2D()(x)
x = kr.layers.Dense(256, activation='relu')(x)
x = kr.layers.Dropout(0.5)(x)
outputs = kr.layers.Dense(5, activation='softmax')(x)

model_antrenare = kr.models.Model(inputs = inputs, outputs = outputs)

optimizator = tf.keras.optimizers.AdamW(learning_rate=0.0002,weight_decay=1e-4)

model_antrenare.compile(optimizer=optimizator, loss='sparse_categorical_crossentropy',metrics=['accuracy'])

reduce_lr = kr.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5,patience=10,min_lr=1e-6,verbose=1)

early_stop = kr.callbacks.EarlyStopping(monitor='val_loss', patience=20, verbose=1,restore_best_weights=True,start_from_epoch=5)

model_antrenare.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ augumentare_date    │ (None, 256, 256,  │          0 │ input_layer[0][0] │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 256, 256,  │          0 │ augumentare_date… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │      1,792 │ rescaling[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ activation[0][0]  │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 8)         │        520 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │        576 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1, 64)  │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 256, 256,  │          0 │ activation[0][0], │
# │                     │ 64)               │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ multiply[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ activation_1[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 16)        │      2,064 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 128)       │      2,176 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 1, 1, 128) │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 128, 128,  │          0 │ activation_1[0][… │
# │ (Multiply)          │ 128)              │            │ reshape_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ multiply_1[0][0]  │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64,    │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ activation_2[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 32)        │      8,224 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 256)       │      8,448 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 1, 1, 256) │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 64, 64,    │          0 │ activation_2[0][… │
# │ (Multiply)          │ 256)              │            │ reshape_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ multiply_2[0][0]  │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ max_pooling2d_2[… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 256)       │     65,792 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 5)         │      1,285 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 461,693 (1.76 MB)
#  Trainable params: 460,797 (1.76 MB)
#  Non-trainable params: 896 (3.50 KB)

# %%
y_train = np.concatenate([y for x,y in set_date_antrenare],axis=0)
clase_unice = np.unique(y_train)

class_weights_array = compute_class_weight(class_weight='balanced',classes=clase_unice,y=y_train)
class_weights_dict = dict(zip(clase_unice,class_weights_array))

print(class_weights_dict)
# Out:
# {np.int32(0): np.float64(1.0), np.int32(1): np.float64(1.0), np.int32(2): np.float64(1.0), np.int32(3): np.float64(1.0), np.int32(4): np.float64(1.0)}

# %%
model_antrenare_istoric = model_antrenare.fit(x=set_date_antrenare,validation_data = set_date_validare,epochs=60,callbacks=[early_stop,reduce_lr],class_weight=class_weights_dict)
# Out:
# Epoch 1/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 326s 3s/step - accuracy: 0.5343 - loss: 1.1651 - val_accuracy: 0.2000 - val_loss: 1.7264 - learning_rate: 2.0000e-04
# Epoch 2/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 328s 3s/step - accuracy: 0.6057 - loss: 0.9855 - val_accuracy: 0.2217 - val_loss: 2.0615 - learning_rate: 2.0000e-04
# Epoch 3/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 325s 3s/step - accuracy: 0.6400 - loss: 0.9163 - val_accuracy: 0.2567 - val_loss: 1.8964 - learning_rate: 2.0000e-04
# Epoch 4/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 322s 3s/step - accuracy: 0.6677 - loss: 0.8569 - val_accuracy: 0.3600 - val_loss: 1.4446 - learning_rate: 2.0000e-04
# Epoch 5/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 325s 3s/step - accuracy: 0.6750 - loss: 0.8103 - val_accuracy: 0.5267 - val_loss: 1.1274 - learning_rate: 2.0000e-04
# Epoch 6/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 326s 3s/step - accuracy: 0.7053 - loss: 0.7685 - val_accuracy: 0.4817 - val_loss: 1.2147 - learning_rate: 2.0000e-04
# Epoch 7/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 305s 3s/step - accuracy: 0.7117 - loss: 0.7412 - val_accuracy: 0.5817 - val_loss: 1.0361 - learning_rate: 2.0000e-04
# Epoch 8/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 327s 3s/step - accuracy: 0.7130 - loss: 0.7183 - val_accuracy: 0.6350 - val_loss: 0.8446 - learning_rate: 2.0000e-04
# Epoch 9/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 325s 3s/step - accuracy: 0.7393 - loss: 0.6684 - val_accuracy: 0.5517 - val_loss: 1.1099 - learning_rate: 2.0000e-04
# Epoch 10/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 326s 3s/step - accuracy: 0.7533 - loss: 0.6231 - val_accuracy: 0.6200 - val_loss: 1.0507 - learning_rate: 2.0000e-04
# Epoch 11/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 327s 3s/step - accuracy: 0.7673 - loss: 0.5976 - val_accuracy: 0.5100 - val_loss: 1.5122 - learning_rate: 2.0000e-04
# Epoch 12/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 326s 3s/step - accuracy: 0.7710 - loss: 0.5751 - val_accuracy: 0.6700 - val_loss: 0.7963 - learning_rate: 2.0000e-04
# Epoch 13/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 321s 3s/step - accuracy: 0.7930 - loss: 0.5382 - val_accuracy: 0.6317 - val_loss: 1.0709 - learning_rate: 2.0000e-04
# Epoch 14/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 326s 3s/step - accuracy: 0.8017 - loss: 0.5149 - val_accuracy: 0.6717 - val_loss: 1.0859 - learning_rate: 2.0000e-04
# Epoch 15/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 328s 3s/step - accuracy: 0.8183 - loss: 0.4955 - val_accuracy: 0.6817 - val_loss: 0.8312 - learning_rate: 2.0000e-04
# Epoch 16/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 324s 3s/step - accuracy: 0.8163 - loss: 0.4782 - val_accuracy: 0.7567 - val_loss: 0.7285 - learning_rate: 2.0000e-04
# Epoch 17/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 327s 3s/step - accuracy: 0.8253 - loss: 0.4622 - val_accuracy: 0.5850 - val_loss: 1.0272 - learning_rate: 2.0000e-04
# Epoch 18/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 310s 3s/step - accuracy: 0.8277 - loss: 0.4485 - val_accuracy: 0.7483 - val_loss: 0.7721 - learning_rate: 2.0000e-04
# Epoch 19/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 328s 3s/step - accuracy: 0.8343 - loss: 0.4259 - val_accuracy: 0.6883 - val_loss: 0.8894 - learning_rate: 2.0000e-04
# Epoch 20/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 326s 3s/step - accuracy: 0.8453 - loss: 0.4061 - val_accuracy: 0.6550 - val_loss: 1.1523 - learning_rate: 2.0000e-04
# Epoch 21/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 327s 3s/step - accuracy: 0.8380 - loss: 0.4300 - val_accuracy: 0.6167 - val_loss: 1.0817 - learning_rate: 2.0000e-04
# Epoch 22/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 329s 3s/step - accuracy: 0.8627 - loss: 0.3805 - val_accuracy: 0.6883 - val_loss: 0.9473 - learning_rate: 2.0000e-04
# Epoch 23/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 326s 3s/step - accuracy: 0.8463 - loss: 0.3864 - val_accuracy: 0.7417 - val_loss: 0.7243 - learning_rate: 2.0000e-04
# Epoch 24/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 328s 3s/step - accuracy: 0.8540 - loss: 0.3914 - val_accuracy: 0.6683 - val_loss: 1.0383 - learning_rate: 2.0000e-04
# Epoch 25/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 332s 4s/step - accuracy: 0.8587 - loss: 0.3776 - val_accuracy: 0.6933 - val_loss: 1.1294 - learning_rate: 2.0000e-04
# Epoch 26/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 330s 3s/step - accuracy: 0.8690 - loss: 0.3557 - val_accuracy: 0.7267 - val_loss: 0.8174 - learning_rate: 2.0000e-04
# Epoch 27/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 327s 3s/step - accuracy: 0.8603 - loss: 0.3596 - val_accuracy: 0.5800 - val_loss: 1.3658 - learning_rate: 2.0000e-04
# Epoch 28/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 327s 3s/step - accuracy: 0.8687 - loss: 0.3469 - val_accuracy: 0.7333 - val_loss: 0.9111 - learning_rate: 2.0000e-04
# Epoch 29/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 327s 3s/step - accuracy: 0.8750 - loss: 0.3305 - val_accuracy: 0.7267 - val_loss: 0.9514 - learning_rate: 2.0000e-04
# Epoch 30/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 252s 3s/step - accuracy: 0.8777 - loss: 0.3329 - val_accuracy: 0.6633 - val_loss: 1.1409 - learning_rate: 2.0000e-04
# Epoch 31/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 328s 3s/step - accuracy: 0.8713 - loss: 0.3374 - val_accuracy: 0.7250 - val_loss: 0.9288 - learning_rate: 2.0000e-04
# Epoch 32/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 329s 3s/step - accuracy: 0.8863 - loss: 0.3092 - val_accuracy: 0.6683 - val_loss: 1.3888 - learning_rate: 2.0000e-04
# Epoch 33/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8812 - loss: 0.3008
# Epoch 33: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 328s 3s/step - accuracy: 0.8830 - loss: 0.3026 - val_accuracy: 0.7400 - val_loss: 0.9884 - learning_rate: 2.0000e-04
# Epoch 34/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 328s 3s/step - accuracy: 0.9000 - loss: 0.2709 - val_accuracy: 0.7367 - val_loss: 0.7511 - learning_rate: 1.0000e-04
# Epoch 35/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 326s 3s/step - accuracy: 0.9003 - loss: 0.2666 - val_accuracy: 0.7583 - val_loss: 0.7364 - learning_rate: 1.0000e-04
# Epoch 36/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 329s 3s/step - accuracy: 0.9040 - loss: 0.2625 - val_accuracy: 0.7767 - val_loss: 0.7112 - learning_rate: 1.0000e-04
# Epoch 37/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 327s 3s/step - accuracy: 0.9040 - loss: 0.2579 - val_accuracy: 0.7267 - val_loss: 0.8404 - learning_rate: 1.0000e-04
# Epoch 38/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 327s 3s/step - accuracy: 0.9067 - loss: 0.2466 - val_accuracy: 0.8117 - val_loss: 0.6805 - learning_rate: 1.0000e-04
# Epoch 39/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 326s 3s/step - accuracy: 0.9070 - loss: 0.2442 - val_accuracy: 0.8050 - val_loss: 0.6651 - learning_rate: 1.0000e-04
# Epoch 40/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 326s 3s/step - accuracy: 0.9133 - loss: 0.2403 - val_accuracy: 0.8333 - val_loss: 0.6454 - learning_rate: 1.0000e-04
# Epoch 41/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 326s 3s/step - accuracy: 0.9127 - loss: 0.2344 - val_accuracy: 0.7717 - val_loss: 0.6941 - learning_rate: 1.0000e-04
# Epoch 42/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 326s 3s/step - accuracy: 0.9130 - loss: 0.2332 - val_accuracy: 0.7683 - val_loss: 0.6903 - learning_rate: 1.0000e-04
# Epoch 43/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 327s 3s/step - accuracy: 0.9167 - loss: 0.2213 - val_accuracy: 0.7933 - val_loss: 0.7100 - learning_rate: 1.0000e-04
# Epoch 44/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 330s 4s/step - accuracy: 0.9183 - loss: 0.2294 - val_accuracy: 0.6900 - val_loss: 0.9959 - learning_rate: 1.0000e-04
# Epoch 45/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 329s 3s/step - accuracy: 0.9173 - loss: 0.2224 - val_accuracy: 0.7583 - val_loss: 0.7870 - learning_rate: 1.0000e-04
# Epoch 46/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 330s 3s/step - accuracy: 0.9187 - loss: 0.2269 - val_accuracy: 0.7800 - val_loss: 0.6705 - learning_rate: 1.0000e-04
# Epoch 47/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 303s 3s/step - accuracy: 0.9157 - loss: 0.2316 - val_accuracy: 0.7233 - val_loss: 0.9677 - learning_rate: 1.0000e-04
# Epoch 48/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 324s 3s/step - accuracy: 0.9193 - loss: 0.2268 - val_accuracy: 0.7800 - val_loss: 0.7302 - learning_rate: 1.0000e-04
# Epoch 49/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 330s 3s/step - accuracy: 0.9157 - loss: 0.2338 - val_accuracy: 0.8167 - val_loss: 0.6632 - learning_rate: 1.0000e-04
# Epoch 50/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9219 - loss: 0.2170
# Epoch 50: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 330s 4s/step - accuracy: 0.9193 - loss: 0.2282 - val_accuracy: 0.7083 - val_loss: 1.0330 - learning_rate: 1.0000e-04
# Epoch 51/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 329s 3s/step - accuracy: 0.9257 - loss: 0.1955 - val_accuracy: 0.8267 - val_loss: 0.6034 - learning_rate: 5.0000e-05
# Epoch 52/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 331s 4s/step - accuracy: 0.9307 - loss: 0.1982 - val_accuracy: 0.8333 - val_loss: 0.6102 - learning_rate: 5.0000e-05
# Epoch 53/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 328s 3s/step - accuracy: 0.9353 - loss: 0.1875 - val_accuracy: 0.8200 - val_loss: 0.6544 - learning_rate: 5.0000e-05
# Epoch 54/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 311s 3s/step - accuracy: 0.9340 - loss: 0.1849 - val_accuracy: 0.8400 - val_loss: 0.5863 - learning_rate: 5.0000e-05
# Epoch 55/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 328s 3s/step - accuracy: 0.9297 - loss: 0.1975 - val_accuracy: 0.8383 - val_loss: 0.5735 - learning_rate: 5.0000e-05
# Epoch 56/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 330s 3s/step - accuracy: 0.9370 - loss: 0.1858 - val_accuracy: 0.8100 - val_loss: 0.6123 - learning_rate: 5.0000e-05
# Epoch 57/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 235s 2s/step - accuracy: 0.9307 - loss: 0.1941 - val_accuracy: 0.8133 - val_loss: 0.6641 - learning_rate: 5.0000e-05
# Epoch 58/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 214s 2s/step - accuracy: 0.9410 - loss: 0.1737 - val_accuracy: 0.8300 - val_loss: 0.6428 - learning_rate: 5.0000e-05
# Epoch 59/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 210s 2s/step - accuracy: 0.9377 - loss: 0.1717 - val_accuracy: 0.8267 - val_loss: 0.6348 - learning_rate: 5.0000e-05
# Epoch 60/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 209s 2s/step - accuracy: 0.9340 - loss: 0.1776 - val_accuracy: 0.8200 - val_loss: 0.6903 - learning_rate: 5.0000e-05
# Restoring model weights from the end of the best epoch: 55.

# %%
loss = model_antrenare_istoric.history['loss']
val_loss = model_antrenare_istoric.history['val_loss']
epochs = range(1, len(loss) + 1)


plt.figure(figsize = (10,6))
plt.plot(epochs, loss, 'r', label='Loss Antrenare')
plt.plot(epochs, val_loss, 'b', label='Loss Validare')
plt.title('Loss Antrenare vs Loss Validare')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.show()

# %%
accuracy = model_antrenare_istoric.history['accuracy']
val_accuracy = model_antrenare_istoric.history['val_accuracy']
epochs = range(1, len(accuracy) + 1)


plt.figure(figsize = (10,6))
plt.plot(epochs, accuracy, 'r', label='Accuracy Antrenare')
plt.plot(epochs, val_accuracy, 'b', label='Accuracy Validare')
plt.title('Accuracy Antrenare vs Accuracy Validare')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.show()

# %%
test_loss,test_accuracy = model_antrenare.evaluate(set_date_testare)
print(test_loss)
print(test_accuracy)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 370ms/step - accuracy: 0.8625 - loss: 0.5147
# 0.5147272944450378
# 0.862500011920929

# %%
val_accuracy,val_loss = model_antrenare.evaluate(set_date_validare)
print(val_loss)
print(val_accuracy)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 374ms/step - accuracy: 0.8383 - loss: 0.5735
# 0.8383333086967468
# 0.5735213160514832

# %%
y_corect = np.concatenate([y for x,y in set_date_testare],axis=0)
prediction = model_antrenare.predict(set_date_testare)
y_prediction = np.argmax(prediction,axis=1)

class_name = set_date_testare.class_names
class_name

cm = confusion_matrix(y_corect,y_prediction)


plt.figure(figsize = (10,8))
sns.heatmap(cm,annot=True,fmt='g',cmap='Blues',xticklabels=class_name,yticklabels=class_name)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()


print(classification_report(y_corect,y_prediction,target_names=class_name))
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 370ms/step
#                    precision    recall  f1-score   support
#
#       Anthracnose       0.79      0.74      0.76        80
#    Bacterial Wilt       0.95      0.97      0.96        80
#      Downy Mildew       0.87      0.69      0.77        80
# Gummy Stem Blight       0.78      0.91      0.84        80
#           Healthy       0.93      1.00      0.96        80
#
#          accuracy                           0.86       400
#         macro avg       0.86      0.86      0.86       400
#      weighted avg       0.86      0.86      0.86       400
