# %%
import os

from sklearn.metrics import confusion_matrix, classification_report

os.environ['TF_ENABLE_ONEDNN_OPTS']= '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import keras as kr
from keras.callbacks import EarlyStopping

from sklearn.utils.class_weight import compute_class_weight

# %%
set_date_antrenare = kr.utils.image_dataset_from_directory(
    'D:/Licenta/DataSetOrganized/data/train',
    labels="inferred",
    label_mode="int",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(256, 256),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False,
    pad_to_aspect_ratio=False,
    data_format=None,
    format="tf",
    verbose=True,
)

set_date_validare = kr.utils.image_dataset_from_directory(
    'D:/Licenta/DataSetOrganized/data/validation',
    labels="inferred",
    label_mode="int",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(256, 256),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False,
    pad_to_aspect_ratio=False,
    data_format=None,
    format="tf",
    verbose=True,
)

set_date_testare = kr.utils.image_dataset_from_directory(
    'D:/Licenta/DataSetOrganized/data/test',
    labels="inferred",
    label_mode="int",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(256, 256),
    shuffle=False,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False,
    pad_to_aspect_ratio=False,
    data_format=None,
    format="tf",
    verbose=True,
)
# Out:
# Found 3000 files belonging to 5 classes.
# Found 600 files belonging to 5 classes.
# Found 400 files belonging to 5 classes.

# %%
model_data_augumentation = kr.Sequential([kr.layers.RandomFlip("horizontal_and_vertical"),kr.layers.RandomBrightness(0.1),kr.layers.RandomContrast(0.1)],name="augumentare_date")

# %%
def squeeze_excite_block(tensor,ratio=16):
    filters = tensor.shape[-1]
    s_e_b = kr.layers.GlobalAvgPool2D()(tensor)
    s_e_b = kr.layers.Dense(filters // ratio,activation = 'relu' , kernel_initializer='he_normal')(s_e_b)
    s_e_b = kr.layers.Dense(filters,activation='sigmoid')(s_e_b)
    s_e_b = kr.layers.Reshape((1,1,filters))(s_e_b)
    return kr.layers.Multiply()([tensor,s_e_b])

# %%
inputs = kr.layers.Input(shape=(256,256,3))


x = model_data_augumentation(inputs)
x =  kr.layers.Rescaling(1./255)(x)

x = kr.layers.Conv2D(64,3,padding ='same',kernel_initializer='he_normal')(x)
x = kr.layers.BatchNormalization()(x)
x = kr.layers.Activation('relu')(x)
x = squeeze_excite_block(x)
x = kr.layers.MaxPooling2D(2,2)(x)

x = kr.layers.Conv2D(128,3,padding ='same',kernel_initializer='he_normal')(x)
x = kr.layers.BatchNormalization()(x)
x = kr.layers.Activation('relu')(x)
x = squeeze_excite_block(x)
x = kr.layers.MaxPooling2D(2,2)(x)


x = kr.layers.Conv2D(256,3,padding ='same',kernel_initializer='he_normal')(x)
x = kr.layers.BatchNormalization()(x)
x = kr.layers.Activation('relu')(x)
x = squeeze_excite_block(x)
x = kr.layers.MaxPooling2D(2,2)(x)


x = kr.layers.GlobalAveragePooling2D()(x)
x = kr.layers.Dense(256, activation='relu')(x)
x = kr.layers.Dropout(0.5)(x)
outputs = kr.layers.Dense(5, activation='softmax')(x)

model_antrenare = kr.models.Model(inputs = inputs, outputs = outputs)

optimizator = tf.keras.optimizers.AdamW(learning_rate=0.0002,weight_decay=1e-4)

model_antrenare.compile(optimizer=optimizator, loss='sparse_categorical_crossentropy',metrics=['accuracy'])

reduce_lr = kr.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5,patience=10,min_lr=1e-6,verbose=1)

early_stop = kr.callbacks.EarlyStopping(monitor='val_loss', patience=20, verbose=1,restore_best_weights=True,start_from_epoch=5)

model_antrenare.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ augumentare_date    │ (None, 256, 256,  │          0 │ input_layer[0][0] │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 256, 256,  │          0 │ augumentare_date… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │      1,792 │ rescaling[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ activation[0][0]  │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 4)         │        260 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │        320 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1, 64)  │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 256, 256,  │          0 │ activation[0][0], │
# │                     │ 64)               │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ multiply[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ activation_1[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 8)         │      1,032 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 128)       │      1,152 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 1, 1, 128) │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 128, 128,  │          0 │ activation_1[0][… │
# │ (Multiply)          │ 128)              │            │ reshape_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ multiply_1[0][0]  │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64,    │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ activation_2[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 16)        │      4,112 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 256)       │      4,352 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 1, 1, 256) │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 64, 64,    │          0 │ activation_2[0][… │
# │ (Multiply)          │ 256)              │            │ reshape_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ multiply_2[0][0]  │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ max_pooling2d_2[… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 256)       │     65,792 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 5)         │      1,285 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 450,913 (1.72 MB)
#  Trainable params: 450,017 (1.72 MB)
#  Non-trainable params: 896 (3.50 KB)

# %%
y_train = np.concatenate([y for x,y in set_date_antrenare],axis=0)
clase_unice = np.unique(y_train)

class_weights_array = compute_class_weight(class_weight='balanced',classes=clase_unice,y=y_train)
class_weights_dict = dict(zip(clase_unice,class_weights_array))

print(class_weights_dict)
# Out:
# {np.int32(0): np.float64(1.0), np.int32(1): np.float64(1.0), np.int32(2): np.float64(1.0), np.int32(3): np.float64(1.0), np.int32(4): np.float64(1.0)}

# %%
model_antrenare_istoric = model_antrenare.fit(x=set_date_antrenare,validation_data = set_date_validare,epochs=60,callbacks=[early_stop,reduce_lr],class_weight=class_weights_dict)
# Out:
# Epoch 1/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 330s 3s/step - accuracy: 0.5420 - loss: 1.1612 - val_accuracy: 0.2067 - val_loss: 1.6523 - learning_rate: 2.0000e-04
# Epoch 2/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 326s 3s/step - accuracy: 0.6143 - loss: 0.9933 - val_accuracy: 0.2017 - val_loss: 2.1940 - learning_rate: 2.0000e-04
# Epoch 3/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 323s 3s/step - accuracy: 0.6460 - loss: 0.9089 - val_accuracy: 0.2083 - val_loss: 2.1021 - learning_rate: 2.0000e-04
# Epoch 4/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 322s 3s/step - accuracy: 0.6653 - loss: 0.8569 - val_accuracy: 0.4817 - val_loss: 1.1753 - learning_rate: 2.0000e-04
# Epoch 5/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 325s 3s/step - accuracy: 0.6707 - loss: 0.8298 - val_accuracy: 0.6100 - val_loss: 0.9086 - learning_rate: 2.0000e-04
# Epoch 6/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 323s 3s/step - accuracy: 0.6820 - loss: 0.8006 - val_accuracy: 0.6150 - val_loss: 0.9407 - learning_rate: 2.0000e-04
# Epoch 7/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 328s 3s/step - accuracy: 0.7030 - loss: 0.7609 - val_accuracy: 0.5883 - val_loss: 0.9503 - learning_rate: 2.0000e-04
# Epoch 8/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 325s 3s/step - accuracy: 0.7280 - loss: 0.7056 - val_accuracy: 0.6283 - val_loss: 0.8372 - learning_rate: 2.0000e-04
# Epoch 9/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 325s 3s/step - accuracy: 0.7223 - loss: 0.7089 - val_accuracy: 0.6300 - val_loss: 0.8804 - learning_rate: 2.0000e-04
# Epoch 10/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 328s 3s/step - accuracy: 0.7350 - loss: 0.6765 - val_accuracy: 0.5933 - val_loss: 0.9165 - learning_rate: 2.0000e-04
# Epoch 11/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 328s 3s/step - accuracy: 0.7417 - loss: 0.6704 - val_accuracy: 0.6550 - val_loss: 0.9761 - learning_rate: 2.0000e-04
# Epoch 12/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 327s 3s/step - accuracy: 0.7443 - loss: 0.6272 - val_accuracy: 0.6700 - val_loss: 0.8784 - learning_rate: 2.0000e-04
# Epoch 13/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 329s 3s/step - accuracy: 0.7813 - loss: 0.5785 - val_accuracy: 0.6617 - val_loss: 0.8184 - learning_rate: 2.0000e-04
# Epoch 14/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 326s 3s/step - accuracy: 0.7707 - loss: 0.5688 - val_accuracy: 0.6817 - val_loss: 0.8654 - learning_rate: 2.0000e-04
# Epoch 15/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 326s 3s/step - accuracy: 0.7740 - loss: 0.5639 - val_accuracy: 0.7033 - val_loss: 0.9231 - learning_rate: 2.0000e-04
# Epoch 16/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 324s 3s/step - accuracy: 0.7967 - loss: 0.5291 - val_accuracy: 0.6750 - val_loss: 0.7827 - learning_rate: 2.0000e-04
# Epoch 17/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 326s 3s/step - accuracy: 0.8233 - loss: 0.4780 - val_accuracy: 0.6617 - val_loss: 0.8165 - learning_rate: 2.0000e-04
# Epoch 18/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 235s 2s/step - accuracy: 0.8137 - loss: 0.4918 - val_accuracy: 0.7400 - val_loss: 0.7967 - learning_rate: 2.0000e-04
# Epoch 19/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 210s 2s/step - accuracy: 0.8230 - loss: 0.4619 - val_accuracy: 0.6917 - val_loss: 0.8766 - learning_rate: 2.0000e-04
# Epoch 20/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 209s 2s/step - accuracy: 0.8227 - loss: 0.4550 - val_accuracy: 0.6067 - val_loss: 0.9842 - learning_rate: 2.0000e-04
# Epoch 21/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 208s 2s/step - accuracy: 0.8407 - loss: 0.4286 - val_accuracy: 0.7100 - val_loss: 0.7932 - learning_rate: 2.0000e-04
# Epoch 22/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 309s 3s/step - accuracy: 0.8333 - loss: 0.4330 - val_accuracy: 0.7267 - val_loss: 0.7960 - learning_rate: 2.0000e-04
# Epoch 23/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 325s 3s/step - accuracy: 0.8457 - loss: 0.4141 - val_accuracy: 0.6383 - val_loss: 1.2398 - learning_rate: 2.0000e-04
# Epoch 24/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 326s 3s/step - accuracy: 0.8567 - loss: 0.3793 - val_accuracy: 0.7150 - val_loss: 0.9445 - learning_rate: 2.0000e-04
# Epoch 25/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 327s 3s/step - accuracy: 0.8623 - loss: 0.3732 - val_accuracy: 0.6533 - val_loss: 1.2498 - learning_rate: 2.0000e-04
# Epoch 26/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8580 - loss: 0.3870
# Epoch 26: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 326s 3s/step - accuracy: 0.8617 - loss: 0.3791 - val_accuracy: 0.6967 - val_loss: 0.8452 - learning_rate: 2.0000e-04
# Epoch 27/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 322s 3s/step - accuracy: 0.8777 - loss: 0.3186 - val_accuracy: 0.6733 - val_loss: 0.9783 - learning_rate: 1.0000e-04
# Epoch 28/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 328s 3s/step - accuracy: 0.8817 - loss: 0.3165 - val_accuracy: 0.7550 - val_loss: 0.7083 - learning_rate: 1.0000e-04
# Epoch 29/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 328s 3s/step - accuracy: 0.8880 - loss: 0.3209 - val_accuracy: 0.6317 - val_loss: 1.1683 - learning_rate: 1.0000e-04
# Epoch 30/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 328s 3s/step - accuracy: 0.8817 - loss: 0.3236 - val_accuracy: 0.7733 - val_loss: 0.6692 - learning_rate: 1.0000e-04
# Epoch 31/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 322s 3s/step - accuracy: 0.8883 - loss: 0.3054 - val_accuracy: 0.7950 - val_loss: 0.6436 - learning_rate: 1.0000e-04
# Epoch 32/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 289s 3s/step - accuracy: 0.8910 - loss: 0.2920 - val_accuracy: 0.7333 - val_loss: 0.8779 - learning_rate: 1.0000e-04
# Epoch 33/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 243s 3s/step - accuracy: 0.8890 - loss: 0.3073 - val_accuracy: 0.7733 - val_loss: 0.7250 - learning_rate: 1.0000e-04
# Epoch 34/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 325s 3s/step - accuracy: 0.8870 - loss: 0.3070 - val_accuracy: 0.7750 - val_loss: 0.7209 - learning_rate: 1.0000e-04
# Epoch 35/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 324s 3s/step - accuracy: 0.8913 - loss: 0.2928 - val_accuracy: 0.8083 - val_loss: 0.6519 - learning_rate: 1.0000e-04
# Epoch 36/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 324s 3s/step - accuracy: 0.8960 - loss: 0.2768 - val_accuracy: 0.7883 - val_loss: 0.7015 - learning_rate: 1.0000e-04
# Epoch 37/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 322s 3s/step - accuracy: 0.8963 - loss: 0.2718 - val_accuracy: 0.7917 - val_loss: 0.6632 - learning_rate: 1.0000e-04
# Epoch 38/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 326s 3s/step - accuracy: 0.9013 - loss: 0.2679 - val_accuracy: 0.7817 - val_loss: 0.6550 - learning_rate: 1.0000e-04
# Epoch 39/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 327s 3s/step - accuracy: 0.8967 - loss: 0.2685 - val_accuracy: 0.8117 - val_loss: 0.6352 - learning_rate: 1.0000e-04
# Epoch 40/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 325s 3s/step - accuracy: 0.8933 - loss: 0.2792 - val_accuracy: 0.7200 - val_loss: 0.9442 - learning_rate: 1.0000e-04
# Epoch 41/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 326s 3s/step - accuracy: 0.9017 - loss: 0.2656 - val_accuracy: 0.7783 - val_loss: 0.7452 - learning_rate: 1.0000e-04
# Epoch 42/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 324s 3s/step - accuracy: 0.9010 - loss: 0.2646 - val_accuracy: 0.8000 - val_loss: 0.6738 - learning_rate: 1.0000e-04
# Epoch 43/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 328s 3s/step - accuracy: 0.9107 - loss: 0.2542 - val_accuracy: 0.8067 - val_loss: 0.6136 - learning_rate: 1.0000e-04
# Epoch 44/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 325s 3s/step - accuracy: 0.9157 - loss: 0.2403 - val_accuracy: 0.7817 - val_loss: 0.6508 - learning_rate: 1.0000e-04
# Epoch 45/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 324s 3s/step - accuracy: 0.9037 - loss: 0.2555 - val_accuracy: 0.8267 - val_loss: 0.6609 - learning_rate: 1.0000e-04
# Epoch 46/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 323s 3s/step - accuracy: 0.9063 - loss: 0.2564 - val_accuracy: 0.8083 - val_loss: 0.7696 - learning_rate: 1.0000e-04
# Epoch 47/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 328s 3s/step - accuracy: 0.9077 - loss: 0.2498 - val_accuracy: 0.8133 - val_loss: 0.6640 - learning_rate: 1.0000e-04
# Epoch 48/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 326s 3s/step - accuracy: 0.9093 - loss: 0.2427 - val_accuracy: 0.7983 - val_loss: 0.7907 - learning_rate: 1.0000e-04
# Epoch 49/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 324s 3s/step - accuracy: 0.9163 - loss: 0.2400 - val_accuracy: 0.7683 - val_loss: 0.6987 - learning_rate: 1.0000e-04
# Epoch 50/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 322s 3s/step - accuracy: 0.9177 - loss: 0.2284 - val_accuracy: 0.7900 - val_loss: 0.7535 - learning_rate: 1.0000e-04
# Epoch 51/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 322s 3s/step - accuracy: 0.9123 - loss: 0.2331 - val_accuracy: 0.7600 - val_loss: 0.8946 - learning_rate: 1.0000e-04
# Epoch 52/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 323s 3s/step - accuracy: 0.9240 - loss: 0.2177 - val_accuracy: 0.7800 - val_loss: 0.7027 - learning_rate: 1.0000e-04
# Epoch 53/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 328s 3s/step - accuracy: 0.9237 - loss: 0.2144 - val_accuracy: 0.8400 - val_loss: 0.5649 - learning_rate: 1.0000e-04
# Epoch 54/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 322s 3s/step - accuracy: 0.9247 - loss: 0.2039 - val_accuracy: 0.8217 - val_loss: 0.6126 - learning_rate: 1.0000e-04
# Epoch 55/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 326s 3s/step - accuracy: 0.9257 - loss: 0.2067 - val_accuracy: 0.7283 - val_loss: 0.8102 - learning_rate: 1.0000e-04
# Epoch 56/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 324s 3s/step - accuracy: 0.9253 - loss: 0.2059 - val_accuracy: 0.8283 - val_loss: 0.6180 - learning_rate: 1.0000e-04
# Epoch 57/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 326s 3s/step - accuracy: 0.9290 - loss: 0.1944 - val_accuracy: 0.8117 - val_loss: 0.6699 - learning_rate: 1.0000e-04
# Epoch 58/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 380s 3s/step - accuracy: 0.9210 - loss: 0.2066 - val_accuracy: 0.8250 - val_loss: 0.6205 - learning_rate: 1.0000e-04
# Epoch 59/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 327s 3s/step - accuracy: 0.9287 - loss: 0.1958 - val_accuracy: 0.7783 - val_loss: 0.6427 - learning_rate: 1.0000e-04
# Epoch 60/60
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 323s 3s/step - accuracy: 0.9377 - loss: 0.1792 - val_accuracy: 0.6867 - val_loss: 1.0463 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 53.

# %%
loss = model_antrenare_istoric.history['loss']
val_loss = model_antrenare_istoric.history['val_loss']
epochs = range(1, len(loss) + 1)


plt.figure(figsize = (10,6))
plt.plot(epochs, loss, 'r', label='Loss Antrenare')
plt.plot(epochs, val_loss, 'b', label='Loss Validare')
plt.title('Loss Antrenare vs Loss Validare')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.show()

# %%
accuracy = model_antrenare_istoric.history['accuracy']
val_accuracy = model_antrenare_istoric.history['val_accuracy']
epochs = range(1, len(accuracy) + 1)


plt.figure(figsize = (10,6))
plt.plot(epochs, accuracy, 'r', label='Accuracy Antrenare')
plt.plot(epochs, val_accuracy, 'b', label='Accuracy Validare')
plt.title('Accuracy Antrenare vs Accuracy Validare')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.show()

# %%
test_loss,test_accuracy = model_antrenare.evaluate(set_date_testare)
print(test_loss)
print(test_accuracy)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 428ms/step - accuracy: 0.8750 - loss: 0.4838
# 0.4838244616985321
# 0.875

# %%
val_accuracy,val_loss = model_antrenare.evaluate(set_date_validare)
print(val_accuracy)
print(val_loss)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 400ms/step - accuracy: 0.8400 - loss: 0.5649
# 0.5649373531341553
# 0.8399999737739563

# %%
y_corect = np.concatenate([y for x,y in set_date_testare],axis=0)
prediction = model_antrenare.predict(set_date_testare)
y_prediction = np.argmax(prediction,axis=1)

class_name = set_date_testare.class_names
class_name

cm = confusion_matrix(y_corect,y_prediction)


plt.figure(figsize = (10,8))
sns.heatmap(cm,annot=True,fmt='g',cmap='Blues',xticklabels=class_name,yticklabels=class_name)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()


print(classification_report(y_corect,y_prediction,target_names=class_name))
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 480ms/step
#                    precision    recall  f1-score   support
#
#       Anthracnose       0.86      0.68      0.76        80
#    Bacterial Wilt       1.00      1.00      1.00        80
#      Downy Mildew       0.85      0.78      0.81        80
# Gummy Stem Blight       0.74      0.95      0.83        80
#           Healthy       0.96      0.97      0.97        80
#
#          accuracy                           0.88       400
#         macro avg       0.88      0.88      0.87       400
#      weighted avg       0.88      0.88      0.87       400
